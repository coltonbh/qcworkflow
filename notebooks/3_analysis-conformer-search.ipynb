# %% [markdown]
# # Conformer Search Analysis
#
# After running `scripts/3_compute.py` analyze your results here!

# %%
from pathlib import Path

from qcio import Structure, view, ProgramOutput, align, rmsd, constants

# %%
# Constants
DATA_DIR = Path("../data")
STRUCT_DIR = DATA_DIR / "structures"
CALC_DIR = DATA_DIR / "calcs"

# %% [markdown]
# ## Open and Inspect Results
#
# We are using the same pattern here that we used for `Structure` objects and the `energy/optimization` calculations: open a calculation with `ProgramOuput.open("path/to/file.json")` and then passed to `view.view(...)` to get a visualization.
#
# **Notice that some structures look very similar and are very similar in energy. Is CREST really returning unique conformers??**

# %%
u2_conf = ProgramOutput.open(CALC_DIR / "u2-anion-crest-conformer_search.json")

# %%
view.view(u2_conf)
# Out:
#     <style>
#         table {
#             border-collapse: collapse;
#             width: 100%;
#         }
#         th, td {
#             border: 1px solid black;
#             padding: 8px;
#             text-align: left;
#         }
#         .inner-table {
#             border: none;
#             width: 100%;
#         }
#         .inner-table td {
#             border: none;
#             padding: 2px 5px;
#         }
#         .key, .value {
#             text-align: left;
#             white-space: nowrap;
#         }
#     </style>
#
#     <table>
#         <tr>
#             <th>Structure</th>
#             <th>Success</th>
#             <th>Wall Time</th>
#             <th>Calculation Type</th>
#             <th>Program</th>
#             <th>Model</th>
#             <th>Keywords</th>
#     </tr>
#         <tr>
#             <td><table class='inner-table'><tr><td class='key'>charge</td><td class='value'>-1</td></tr><tr><td class='key'>multiplicity</td><td class='value'>1</td></tr><tr><td class='key'>name</td><td class='value'></td></tr></table></td>
#             <td style="color: green; font-weight: bold;">True</td>
#             <td> 36.00s</td>
#             <td>conformer_search</td>
#             <td>crest 3.0.2</td>
#             <td><table class='inner-table'><tr><td class='key'>method</td><td class='value'>gfnff</td></tr><tr><td class='key'>basis</td><td class='value'>None</td></tr></table></td>
#             <td><table class='inner-table'><tr><td class='key'>topo</td><td class='value'>False</td></tr><tr><td class='key'>preopt</td><td class='value'>False</td></tr><tr><td class='key'>calculation</td><td class='value'>{'level': [{'alpb': 'ch2cl2'}]}</td></tr></table></td>
#         </tr></table><div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_17399071688444908"  style="position: relative; width: 1200px; height: 1800px;">
#         <p id="3dmolwarning_17399071688444908" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17399071688444908 = null;
# var warn = document.getElementById("3dmolwarning_17399071688444908");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_17399071688444908 = null;
# viewergrid_17399071688444908 = $3Dmol.createViewerGrid(document.getElementById("3dmolviewer_17399071688444908"),{rows: 4, cols: 2, control_all: false},{backgroundColor:"white"});
# viewer_17399071688444908 = viewergrid_17399071688444908[0][0];
# viewergrid_17399071688444908[0][0].zoomTo();viewergrid_17399071688444908[0][1].zoomTo();viewergrid_17399071688444908[1][0].zoomTo();viewergrid_17399071688444908[1][1].zoomTo();viewergrid_17399071688444908[2][0].zoomTo();viewergrid_17399071688444908[2][1].zoomTo();viewergrid_17399071688444908[3][0].zoomTo();viewergrid_17399071688444908[3][1].zoomTo();	viewergrid_17399071688444908[0][0].addModel("36\nqcio_charge=-1 qcio_multiplicity=1 Etot= -8.1478302889\nO  0.23920937740000001 2.59269988759999981 -0.16297881040000001\nC  0.74302914929999997 1.47599204430000008 -0.06432213480000000\nN  0.02470668970000000 0.35404301620000000 0.04792735140000000\nC  -1.32442602709999990 0.29311332210000002 0.07660614759999999\nC  -1.94495287129999994 -0.95999236190000004
# %% [markdown]
# ## Conformer Analysis
# Conformers 0,1,2 look very similar! So do 3,4,5. Let's see if we can figure out what's going on!
#
# **See below that the structures look almost identical but with the -CF<sub>3</sub> groups having different numbering. CREST is clearly not considering symmetry when determining the RMSD for structures!**

# %%
view.view(u2_conf.results.conformers[0], u2_conf.results.conformers[1], show_indices=True)
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_1739907712355679"  style="position: relative; width: 1200px; height: 450px;">
#         <p id="3dmolwarning_1739907712355679" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_1739907712355679 = null;
# var warn = document.getElementById("3dmolwarning_1739907712355679");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_1739907712355679 = null;
# viewergrid_1739907712355679 = $3Dmol.createViewerGrid(document.getElementById("3dmolviewer_1739907712355679"),{rows: 1, cols: 2, control_all: false},{backgroundColor:"white"});
# viewer_1739907712355679 = viewergrid_1739907712355679[0][0];
# viewergrid_1739907712355679[0][0].zoomTo();viewergrid_1739907712355679[0][1].zoomTo();	viewergrid_1739907712355679[0][0].addModel("36\nqcio_charge=-1 qcio_multiplicity=1 -8.15032383\nO  0.50684466039999998 -1.24034351989999991 0.02418216500000000\nC  0.65514398200000001 -0.02226024500000000 0.02232608650000000\nN  -0.36252085560000002 0.84736655240000003 0.02204452390000000\nC  -1.67061049330000011 0.50870639829999997 0.01823517190000000\nC  -2.12144360879999994 -0.81665845579999996 0.01229774180000000\nC  -3.46150310750000001 -1.11256497140000010 0.00153709590000000\nC  -3.92322547249999998 -2.55972459700000021 -0.00841967910000000\nF  -2.84476022049999999 -3.36394397770000042 0.05746765920000000\nF  -4.72236396589999963 -2.76650050340000009 1.05543542880000008\nF  -4.60318841630000009 -2.78836996699999995 -1.14794006280000005\nC  -4.39238454220000030 -0.08973751530000000 -0.00424272080000000\nC  -3.97727897549999998 1.22952266529999998 0.00266210120000000\nC  -5.00288958420000007 2.35127217630000018 -0.00519078230000000\nF  -5.76648563100000011 2.23134052169999997 -1.10776612700000010\nF  -4.35877926840000018 3.53479394990000007 -0.01316518460000000\nF  -5.76712833890000010 2.24670241980000007 1.09848133830000005\nC  -2.63620838709999994 1.52376013780000008 0.01369810580000000\nN  1.93257072940000008 0.54763470459999997 0.01859042590000000\nC  3.16123743949999980 -0.12868698980000001 0.01244139230000000\nC  3.23205233010000015 -1.51817970879999997 0.01092679790000000\nC  4.44664562380000028 -2.16456132549999980 0.00508752810000000\nC  5.61709022169999983 -1.43198897200000008 -0.00066505980000000\nC  5.56899088760000005 -0.05127968800000000 0.00018966530000000\nC  6.85798472879999998 0.75636856180000001 -0.01114715560000000\nF  7.54628031009999933 0.45558599630000002 -1.12929443909999994\nF  6.55481716360000011 2.06956775889999989 0.00774864150000000\nF  7.58153158669999883 0.43170944340000000 1.07765011719999992\nC  4.35243985580000015 0.59230678250000002 0.00649537150000000\nH  -1.40669085180000009 -1.62008503439999996 0.01698778940000000\nH  -5.44437414250000007 -0.32140113219999999 -0.01335637320000000\nH  -2.32348349689999978 2.55274531910000002 0.01622461910000000\nH  1.94922006389999969 1.56348824460000002 0.01541251310000000\nH  2.31108037429999991 -2.07429782800000018 0.01441566940000000\nH  4.48523462280000018 -3.24265378059999998 0.00439862070000000\nH  6.57792874140000006 -1.92046318379999992 -0.00639226570000000\nH  4.33419011630000028 1.66743042300000011 0.00632825180000000\n","xyz");
# 	viewergrid_1739907712355679[0][0].addLabel(" ",{"position": {"x": 300.0, "y": 0, "z": 0}, "alignment": "topCenter", "fontSize": 24, "backgroundOpacity": 0, "fontColor": "black", "useScreen": true});
# 	viewergrid_1739907712355679[0][0].addLabel(" ",{"position": {"x": 300.0, "y": 450, "z": 0}, "alignment": "bottomCenter", "fontSize": 20, "backgroundOpacity": 0, "fontColor": "black", "useScreen": true});
# 	viewergrid_1739907712355679[0][0].addLabel("0",{"position": {"x": 0.5068446604, "y": -1.2403435199, "z": 0.024182165}});
# 	viewergrid_1739907712355679[0][0].addLabel("1",{"position": {"x": 0.655143982, "y": -0.022260245, "z": 0.0223260865}});
# 	viewergrid_1739907712355679[0][0].addLabel("2",{"position": {"x": -0.3625208556, "y": 0.8473665524, "z": 0.0220445239}});
# 	viewergrid_1739907712355679[0][0].addLabel("3",{"position": {"x": -1.6706104933, "y": 0.5087063983, "z": 0.0182351719}});
# 	viewergrid_1739907712355679[0][0].addLabel("4",{"position": {"x": -2.1214436088, "y": -0.8166584558, "z": 0.0122977418}});
# 	viewergrid_1739907712355679[0][0].addLabel("5",{"position": {"x": -3.4615031075, "y": -1.1125649714, "z": 0.0015370959}});
# 	viewergrid_1739907712355679[0][0].addLabel("6",{"position": {"x": -3.9232254725, "y": -2.559724597, "z": -0.0084196791}});
# 	viewergrid_1739907712355679[0][0].addLabel("7",{"position": {"x": -2.8447602205, "y": -3.3639439777000004, "z": 0.0574676592}});
# 	viewergrid_1739907712355679[0][0].addLabel("8",{"position": {"x": -4.7223639659, "y": -2.7665005034, "z": 1.0554354288}});
# 	viewergrid_1739907712355679[0][0].addLabel("9",{"position": {"x": -4.6031884163, "y": -2.788369967, "z": -1.1479400628}});
# 	viewergrid_1739907712355679[0][0].addLabel("10",{"position": {"x": -4.3923845422, "y": -0.0897375153, "z": -0.0042427208}});
# 	viewergrid_1739907712355679[0][0].addLabel("11",{"position": {"x": -3.9772789755, "y": 1.2295226653, "z": 0.0026621012}});
# 	viewergrid_1739907712355679[0][0].addLabel("12",{"position": {"x": -5.0028895842, "y": 2.3512721763, "z": -0.0051907823}});
# 	viewergrid_1739907712355679[0][0].addLabel("13",{"position": {"x": -5.766485631, "y": 2.2313405217, "z": -1.107766127}});
# 	viewergrid_1739907712355679[0][0].addLabel("14",{"position": {"x": -4.3587792684, "y": 3.5347939499, "z": -0.013165184599999998}});
# 	viewergrid_1739907712355679[0][0].addLabel("15",{"position": {"x": -5.7671283389, "y": 2.2467024198, "z": 1.0984813383}});
# 	viewergrid_1739907712355679[0][0].addLabel("16",{"position": {"x": -2.6362083871, "y": 1.5237601378, "z": 0.0136981058}});
# 	viewergrid_1739907712355679[0][0].addLabel("17",{"position": {"x": 1.9325707294, "y": 0.5476347046, "z": 0.0185904259}});
# 	viewergrid_1739907712355679[0][0].addLabel("18",{"position": {"x": 3.1612374395, "y": -0.1286869898, "z": 0.0124413923}});
# 	viewergrid_1739907712355679[0][0].addLabel("19",{"position": {"x": 3.2320523301, "y": -1.5181797088, "z": 0.0109267979}});
# 	viewergrid_1739907712355679[0][0].addLabel("20",{"position": {"x": 4.4466456238, "y": -2.1645613255, "z": 0.0050875281000000005}});
# 	viewergrid_1739907712355679[0][0].addLabel("21",{"position": {"x": 5.6170902217, "y": -1.431988972, "z": -0.0006650598000000001}});
# 	viewergrid_1739907712355679[0][0].addLabel("22",{"position": {"x": 5.5689908876, "y": -0.051279688, "z": 0.0001896653}});
# 	viewergrid_1739907712355679[0][0].addLabel("23",{"position": {"x": 6.8579847288, "y": 0.7563685618, "z": -0.0111471556}});
# 	viewergrid_1739907712355679[0][0].addLabel("24",{"position": {"x": 7.546280310099999, "y": 0.4555859963, "z": -1.1292944391}});
# 	viewergrid_1739907712355679[0][0].addLabel("25",{"position": {"x": 6.5548171636, "y": 2.0695677589, "z": 0.0077486415}});
# 	viewergrid_1739907712355679[0][0].addLabel("26",{"position": {"x": 7.581531586699999, "y"

# %% [markdown]
# ### Use qcio's rmsd/align algorithms to quantify similarity and include symmetry

# %%
# rmsd aligns structures and considers symmetry by default. To ignore symmetry pass `symmetry=False` (runs faster)
rmsd_bohr = rmsd(u2_conf.results.conformers[0], u2_conf.results.conformers[1])
print(f"RMSD in Bohr: {rmsd_bohr:.3f}")
print(f"RMSD in Angstrom: {rmsd_bohr * constants.BOHR_TO_ANGSTROM:.3f}")
# Out:
# RMSD in Bohr: 0.666
# RMSD in Angstrom: 0.352

# %% [markdown]
# #### Align structures to get a visual of what this RMSD looks like

# %%
# Align conf0 onto conf1 and consider symmetry. algin(this_struc, onto_this_struct)
conf1_aligned0, rmsd_ang = align(u2_conf.results.conformers[1], u2_conf.results.conformers[0], length_unit='angstrom')
print(f"RMSD in Angstrom: {rmsd_ang:.3f}")
# Out:
# RMSD in Angstrom: 0.352

# %% [markdown]
# ### Clearly the structures are nearly identical! Conf_1 is just a -CF<sub>3</sub> rotation of Conf_0

# %%
view.view(u2_conf.results.conformers[0], conf1_aligned0, same_viewer=True)
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_1739908197744923"  style="position: relative; width: 600px; height: 450px;">
#         <p id="3dmolwarning_1739908197744923" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_1739908197744923 = null;
# var warn = document.getElementById("3dmolwarning_1739908197744923");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1739908197744923 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1739908197744923"),{backgroundColor:"white"});
# viewer_1739908197744923.zoomTo();
# 	viewer_1739908197744923.addModel("36\nqcio_charge=-1 qcio_multiplicity=1 -8.15032383\nO  0.50684466039999998 -1.24034351989999991 0.02418216500000000\nC  0.65514398200000001 -0.02226024500000000 0.02232608650000000\nN  -0.36252085560000002 0.84736655240000003 0.02204452390000000\nC  -1.67061049330000011 0.50870639829999997 0.01823517190000000\nC  -2.12144360879999994 -0.81665845579999996 0.01229774180000000\nC  -3.46150310750000001 -1.11256497140000010 0.00153709590000000\nC  -3.92322547249999998 -2.55972459700000021 -0.00841967910000000\nF  -2.84476022049999999 -3.36394397770000042 0.05746765920000000\nF  -4.72236396589999963 -2.76650050340000009 1.05543542880000008\nF  -4.60318841630000009 -2.78836996699999995 -1.14794006280000005\nC  -4.39238454220000030 -0.08973751530000000 -0.00424272080000000\nC  -3.97727897549999998 1.22952266529999998 0.00266210120000000\nC  -5.00288958420000007 2.35127217630000018 -0.00519078230000000\nF  -5.76648563100000011 2.23134052169999997 -1.10776612700000010\nF  -4.35877926840000018 3.53479394990000007 -0.01316518460000000\nF  -5.76712833890000010 2.24670241980000007 1.09848133830000005\nC  -2.63620838709999994 1.52376013780000008 0.01369810580000000\nN  1.93257072940000008 0.54763470459999997 0.01859042590000000\nC  3.16123743949999980 -0.12868698980000001 0.01244139230000000\nC  3.23205233010000015 -1.
addLabel(" ",{"position": {"x": 300.0, "y": 0, "z": 0}, "alignment": "topCenter", "fontSize": 24, "backgroundOpacity": 0, "fontColor": "black", "useScreen": true});
# 	viewer_1739908197744923.addLabel(" ",{"position": {"x": 300.0, "y": 450, "z": 0}, "alignment": "bottomCenter", "fontSize": 20, "backgroundOpacity": 0, "fontColor": "black", "useScreen": true});
# 	viewer_1739908197744923.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_1739908197744923.zoomTo();
# viewer_1739908197744923.render();
# });
# </script></div>

# %% [markdown]
# ### Now that we know how to do manual conformers analysis, let's use qcio to automatically perform filtering for us taking symmetry into account
#
# We will use a `confomer_rmsd_threshold` of `1.0` Bohr (`0.53` Angstroms).
#
# Looke like there are 4 unique conformers for this structure and that 0,1 and 2,3 are rotational conformers about the N-C bond to the aryl wing!

# %%
view.view(u2_conf, conformer_rmsd_threshold=1.0)
# Out:
#     <style>
#         table {
#             border-collapse: collapse;
#             width: 100%;
#         }
#         th, td {
#             border: 1px solid black;
#             padding: 8px;
#             text-align: left;
#         }
#         .inner-table {
#             border: none;
#             width: 100%;
#         }
#         .inner-table td {
#             border: none;
#             padding: 2px 5px;
#         }
#         .key, .value {
#             text-align: left;
#             white-space: nowrap;
#         }
#     </style>
#
#     <table>
#         <tr>
#             <th>Structure</th>
#             <th>Success</th>
#             <th>Wall Time</th>
#             <th>Calculation Type</th>
#             <th>Program</th>
#             <th>Model</th>
#             <th>Keywords</th>
#     </tr>
#         <tr>
#             <td><table class='inner-table'><tr><td class='key'>charge</td><td class='value'>-1</td></tr><tr><td class='key'>multiplicity</td><td class='value'>1</td></tr><tr><td class='key'>name</td><td class='value'></td></tr></table></td>
#             <td style="color: green; font-weight: bold;">True</td>
#             <td> 36.00s</td>
#             <td>conformer_search</td>
#             <td>crest 3.0.2</td>
#             <td><table class='inner-table'><tr><td class='key'>method</td><td class='value'>gfnff</td></tr><tr><td class='key'>basis</td><td class='value'>None</td></tr></table></td>
#             <td><table class='inner-table'><tr><td class='key'>topo</td><td class='value'>False</td></tr><tr><td class='key'>preopt</td><td class='value'>False</td></tr><tr><td class='key'>calculation</td><td class='value'>{'level': [{'alpb': 'ch2cl2'}]}</td></tr></table></td>
#         </tr></table><div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_17399082240750265"  style="position: relative; width: 1200px; height: 1350px;">
#         <p id="3dmolwarning_17399082240750265" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17399082240750265 = null;
# var warn = document.getElementById("3dmolwarning_17399082240750265");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_17399082240750265 = null;
# viewergrid_17399082240750265 = $3Dmol.createViewerGrid(document.getElementById("3dmolviewer_17399082240750265"),{rows: 3, cols: 2, control_all: false},{backgroundColor:"white"});
# viewer_17399082240750265 = viewergrid_17399082240750265[0][0];
# viewergrid_17399082240750265[0][0].zoomTo();viewergrid_17399082240750265[0][1].zoomTo();viewergrid_17399082240750265[1][0].zoomTo();viewergrid_17399082240750265[1][1].zoomTo();viewergrid_17399082240750265[2][0].zoomTo();viewergrid_17399082240750265[2][1].zoomTo();	viewergrid_17399082240750265[0][0].addModel("36\nqcio_charge=-1 qcio_multiplicity=1 Etot= -8.1478302889\nO  0.23920937740000001 2.59269988759999981 -0.16297881040000001\nC  0.74302914929999997 1.47599204430000008 -0.06432213480000000\nN  0.02470668970000000 0.35404301620000000 0.04792735140000000\nC  -1.32442602709999990 0.29311332210000002 0.07660614759999999\nC  -1.94495287129999994 -0.95999236190000004 0.16400958620000000\nC  -3.31226054700000017 -1.07637336840
# %% [markdown]
# ## More detailed analysis

# %%
filtered_conf, filtered_energies = u2_conf.results.conformers_filtered(threshold=1.0)

# %% [markdown]
# ### RMSD On all Structures
# These look pretty unique! 0,3 are most similar, let's dive in more!

# %%
for i in range(len(filterd_confs)):
    for j in range(i + 1, len(filterd_confs)):
        print(f"RMSD Conf ({i}, {j}): {rmsd(filterd_confs[i], filterd_confs[j]):.3f} Bohr")
# Out:
# RMSD Conf (0, 1): 3.416 Bohr
# RMSD Conf (0, 2): 4.454 Bohr
# RMSD Conf (0, 3): 1.846 Bohr
# RMSD Conf (1, 2): 2.083 Bohr
# RMSD Conf (1, 3): 4.148 Bohr
# RMSD Conf (2, 3): 4.331 Bohr

# %%
fconf3_alinged0, rmsd_val3_0 = align(filterd_confs[3], filterd_confs[0])
print(f"RMSD: {rmsd_val3_0:.3f} Bohr")
# Out:
# RMSD: 1.846 Bohr

# %% [markdown]
# #### qcio makes it easy to see how structures are similar/different

# %%
view.view(filterd_confs[0], fconf3_alinged0, same_viewer=True)
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_17399120024650993"  style="position: relative; width: 600px; height: 450px;">
#         <p id="3dmolwarning_17399120024650993" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17399120024650993 = null;
# var warn = document.getElementById("3dmolwarning_17399120024650993");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17399120024650993 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17399120024650993"),{backgroundColor:"white"});
# viewer_17399120024650993.zoomTo();
# 	viewer_17399120024650993.addModel("36\nqcio_charge=-1 qcio_multiplicity=1 -8.15032383\nO  0.50684466039999998 -1.24034351989999991 0.02418216500000000\nC  0.65514398200000001 -0.02226024500000000 0.02232608650000000\nN  -0.36252085560000002 0.84736655240000003 0.02204452390000000\nC  -1.67061049330000011 0.50870639829999997 0.01823517190000000\nC  -2.12144360879999994 -0.81665845579999996 0.01229774180000000\nC  -3.46150310750000001 -1.11256497140000010 0.00153709590000000\nC  -3.92322547249999998 -2.55972459700000021 -0.00841967910000000\nF  -2.84476022049999999 -3.36394397770000042 0.05746765920000000\nF  -4.72236396589999963 -2.76650050340000009 1.05543542880000008\nF  -4.60318841630000009 -2.78836996699999995 -1.14794006280000005\nC  -4.39238454220000030 -0.08973751530000000 -0.00424272080000000\nC  -3.97727897549999998 1.22952266529999998 0.00266210120000000\nC  -5.00288958420000007 2.35127217630000018 -0.00519078230000000\nF  -5.76648563100000011 2.23134052169999997 -1.10776612700000010\nF  -4.35877926840000018 3.53479394990000007 -0.01316518460000000\nF  -5.76712833890000010 2.24670241980000007 1.09848133830000005\nC  -2.63620838709999994 1.52376013780000008 0.01369810580000000\nN  1.93257072940000008 0.54763470459999997 0.01859042590000000\nC  3.16123743949999980 -0.12868698980000001 0.01244139230000000\nC  3.23205233010000015 -1.51817970879999997 0.01092679790000000\nC  4.44664562380000028 -2.16456132549999980 0.00508752810000000\nC  5.61709022169999983 -1.43198897200000008 -0.00066505980000000\nC  5.56899088760000005 -0.05127968800000000 0.00018966530000000\nC  6.85798472879999998 0.75636856180000001 -0.01114715560000000\nF  7.54628031009999933 0.45558599630000002 -1.12929443909999994\nF  6.55481716360000011 2