# %% [markdown]
# # Analyze Results
#
# After running `scripts/4_compute.py` analyze your results here!

# %%
import numpy as np
from pathlib import Path

from qcio import Structure, view, ProgramOutput, align, rmsd, constants

# %%
# Constants
DATA_DIR = Path("../data")
STRUCT_DIR = DATA_DIR / "structures"
CALC_DIR = DATA_DIR / "calcs"

# %% [markdown]
# ## Open and Inspect Results
# **Notice that CREST found 484 conformers! This is way too many to inspect by hand AND `py3dmol` (the visualizer) does not get happy past ~20 structures (hopefully they will fixed soon??)**

# %%
u2rc_conf = ProgramOutput.open(CALC_DIR / "u2-rc-crest-conformer_search.json")

# %%
print(f"Conformers found: {len(u2rc_conf.results.conformers)}")
# Out:
# Conformers found: 484

# %% [markdown]
# ### Let's look at a few to get started

# %%
# u2rc_conf.results.conformers is a list. If we pass a list of structure view.view will animate
# it for us. Passing * infront of the list unpacks it and passes the list as individual Structures.
view.view(*u2rc_conf.results.conformers[:6])
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_17399132537056546"  style="position: relative; width: 1200px; height: 1350px;">
#         <p id="3dmolwarning_17399132537056546" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17399132537056546 = null;
# var warn = document.getElementById("3dmolwarning_17399132537056546");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_17399132537056546 = null;
# viewergrid_17399132537056546 = $3Dmol.createViewerGrid(document.getElementById("3dmolviewer_17399132537056546"),{rows: 3, cols: 2, control_all: false},{backgroundColor:"white"});
# viewer_17399132537056546 = viewergrid_17399132537056546[0][0];
# viewergrid_17399132537056546[0][0].zoomTo();viewergrid_17399132537056546[0][1].zoomTo();viewergrid_17399132537056546[1][0].zoomTo();viewergrid_17399132537056546[1][1].zoomTo();viewergrid_17399132537056546[2][0].zoomTo();viewergrid_17399132537056546[2][1].zoomTo();	viewergrid_17399132537056546[0][0].addModel("60\nqcio_charge=-1 qcio_multiplicity=1 qcio__identifiers_name=U2 Reaction Complex qcio__identifiers_smiles=[O-]/C(=N\\c1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc2cccc(C(F)(F)F)c2.C[C@@H]1OC(=O)[C@H](C)OC1=O.CO qcio__identifiers_canonical_smiles=C[C@@H]1OC(=O)[C@@H](OC1=O)C.[O-]/C(=N\\c1cc(cc(c1)C(F)(F)F)C(F)(F)F)/Nc1cccc(c1)C(F)(F)F.CO qcio__identifiers_canonical_smiles_program=openbabel -12.00057891\nO  1.15973473230000002 -2.30311115559999990 -0.01506146170000000\nC  0.70561675729999995 -1.17447054279999996 -0.17380578299999999\nN  1.46402365150000002 -0.07581125360000000 -0.26625576509999999\nC  2.81272165999999979 -0.05275216520000000 -0.19725969030000001\nC  3.59297267899999984 -1.19801113919999991 -0.00079219700000000\nC  4.96201667620000020 -1.12216088890000010 0.06229430290000000\nC  5.78761634960000038 -2.38101330759999996 0.26649645270000000\nF  4.95695312680000022 -3.42254542329999989 0.46441177490000002\nF  6.53716541350000035 -2.58856079099999992 -0.83267767029999995\nF  6.58149611330000006 -2.20941715079999978 1.34046659250000011\nC  5.59101052270000043 0.10277849600000000 -0.07012622260000001\nC  4.84554161009999973 1.25141584219999991 -0.26466672590000001\nC  5.53755227789999971 2.59632970700000021 -0.41543845889999997\nF  6.34300975810000001 2.54930862070000019 -
cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc2cccc(C(F)(F)F)c2.C[C@@H]1OC(=O)[C@H](C)OC1=O.CO qcio__identifiers_canonical_smiles=C[C@@H]1OC(=O)[C@@H](OC1=O)C.[O-]/C(=N\\c1cc(cc(c1)C(F)(F)F)C(F)(F)F)/Nc1cccc(c1)C(F)(F)F.CO qcio__identifiers_canonical_smiles_program=openbabel -12.00031012\nO  1.11304740980000005 -2.50530845129999991 -0.36842327860000001\nC  0.65450968529999998 -1.37949662619999991 -0.20086526499999999\nN  1.40577144150000000 -0.29003452330000001 -0.00394911000000000\nC  2.75476499389999940 -0.26299270320000001 0.04401960150000000\nC  3.55125925259999997 -1.40330077070000003 -0.10696536140000000\nC  4.91971929919999962 -1.32321938339999989 -0.04482240680000000\nC  5.76710476680000017 -2.57044102610000014 -0.22826871960000000\nF  6.66254055779999987 -2.63750484339999991 0.77504095910000004\nF  4.96441721520000012 -3.65165668069999994 -0.20929140030000001\nF  6.40469982060000032 -2.48794019159999991 -1.41129291409999991\nC  5.52795389569999962 -0.10031373470000000 0.17364163690000001\nC  4.76517413779999988 1.043746027

# %% [markdown]
# ### We need to start generating statistics on these conformers to understand them.
#
# Let's generate structures for a binding energy caculation to see how this varies across conformers. These indices are ugly due to how `openbabel` generated the structure. In a dream world the indices are continuous across a fragment!

# %%
# See the indices for the complex so we can extract fragments
view.view(u2rc_conf.results.conformers[0], show_indices=True)
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_17399132560953107"  style="position: relative; width: 600px; height: 450px;">
#         <p id="3dmolwarning_17399132560953107" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17399132560953107 = null;
# var warn = document.getElementById("3dmolwarning_17399132560953107");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17399132560953107 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17399132560953107"),{backgroundColor:"white"});
# viewer_17399132560953107.zoomTo();
# 	viewer_17399132560953107.addModel("60\nqcio_charge=-1 qcio_multiplicity=1 qcio__identifiers_name=U2 Reaction Complex qcio__identifiers_smiles=[O-]/C(=N\\c1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc2cccc(C(F)(F)F)c2.C[C@@H]1OC(=O)[C@H](C)OC1=O.CO qcio__identifiers_canonical_smiles=C[C@@H]1OC(=O)[C@@H](OC1=O)C.[O-]/C(=N\\c1cc(cc(c1)C(F)(F)F)C(F)(F)F)/Nc1cccc(c1)C(F)(F)F.CO qcio__identifiers_canonical_smiles_program=openbabel -12.00057891\nO  1.15973473230000002 -2.30311115559999990 -0.01506146170000000\nC  0.70561675729999995 -1.17447054279999996 -0.17380578299999999\nN  1.46402365150000002 -0.07581125360000000 -0.26625576509999999\nC  2.81272165999999979 -0.05275216520000000 -0.19725969030000001\nC  3.59297267899999984 -1.19801113919999991 -0.00079219700000000\nC  4.96201667620000020 -1.12216088890000010 0.06229430290000000\nC  5.78761634960000038 -2.38101330759999996 0.26649645270000000\nF  4.95695312680000022 -3.42254542329999989 0.46441177490000002\nF  6.53716541350000035 -2.58856079099999992 -0.83267767029999995\nF  6.58149611330000006 -2.20941715079999978 1.34046659250000011\nC  5.59101052270000043 0.10277849600000000 -0.07012622260000001\nC  4.84554161009999973 1.25141584219999991 -0.26466672590000001\nC  5.53755227789999971 2.59632970700000021 -0.41543845889999997\nF  6.34300975810000001 2.54930862070000019 -1.49346929640000003\nF  4.60344033570000022 3.55436719380000010 -0.57542250340000001\nF  6.26354016420000015 2.83670773289999989 0.69278313889999998\nC  3.47653788439999989 1.17367241169999992 -0.32726785120000002\nN  -0.67175840610000004 -0.95688184539999999 -0
# 	viewer_17399132560953107.addLabel("4",{"position": {"x": 3.592972679, "y": -1.1980111392, "z": -0.000792197}});
# 	viewer_17399132560953107.addLabel("5",{"position": {"x": 4.9620166762, "y": -1.1221608889, "z": 0.0622943029}});
# 	viewer_17399132560953107.addLabel("6",{"position": {"x": 5.7876163496, "y": -2.3810133076, "z": 0.2664964527}});
# 	viewer_17399132560953107.addLabel("7",{"position": {"x": 4.9569531268, "y": -3.4225454233, "z": 0.4644117749}});
# 	viewer_17399132560953107.addLabel("8",{"position": {"x": 6.5371654135, "y": -2.588560791, "z": -0.8326776703}});
# 	viewer_17399132560953107.addLabel("9",{"position": {"x": 6.5814961133, "y": -2.2094171508, "z": 1.3404665925}});
# 	viewer_17399132560953107.addLabel("10",{"position": {"x": 5.5910105227, "y": 0.102778496, "z": -0.07012622260000001}});
# 	viewer_17399132560953107.addLabel("11",{"position": {"x": 4.8455416101, "y": 1.2514158422, "z": -0.2646667259}});
# 	viewer_17399132560953107.addLabel("12",{"position": {"x": 5.5375522779, "y": 2.596329707, "z": -0.4154384589}});
# 	viewer_17399132560953107.addLabel("13",{"position": {"x": 6.3430097581, "y": 2.5493086207, "z": -1.4934692964

# %% [markdown]
# ### Create Fragment Function and Sanity Check It

# %%
def generate_fragments(structure: Structure):
    # Generate fragments for the complex
    syms = structure.symbols
    geom = structure.geometry
    # Slide notation (starts_with, up_to_not_including)
    meoh_idxs = [(38, 40), (57, 61)]
    lla_idxs = [(28, 38), (48, 56)]
    cat_idxs = [(0,28), (40, 48)]
    
    meoh = Structure(
        symbols=syms[meoh_idxs[0][0]:meoh_idxs[0][1]] + syms[meoh_idxs[1][0]:meoh_idxs[1][1]], 
        geometry=np.vstack((geom[meoh_idxs[0][0]:meoh_idxs[0][1]], geom[meoh_idxs[1][0]:meoh_idxs[1][1]]))
    )
    lla = Structure(
        symbols=syms[lla_idxs[0][0]:lla_idxs[0][1]] + syms[lla_idxs[1][0]:lla_idxs[1][1]], 
        geometry=np.vstack((geom[lla_idxs[0][0]:lla_idxs[0][1]], geom[lla_idxs[1][0]:lla_idxs[1][1]]))
    )
    cat = Structure(
        symbols=syms[cat_idxs[0][0]:cat_idxs[0][1]] + syms[cat_idxs[1][0]:cat_idxs[1][1]], 
        geometry=np.vstack((geom[cat_idxs[0][0]:cat_idxs[0][1]], geom[cat_idxs[1][0]:cat_idxs[1][1]]))
    )
    return {
        "cat": cat,
        "lla": lla,
        "meoh": meoh,
        "complex": structure
    }

# %%
frags = generate_fragments(u2rc_conf.results.conformers[0])

# %% [markdown]
# ### Looks Good!

# %%
view.view(frags['complex'], frags['cat'], frags['lla'], frags['meoh'])
# Out:
# <div style="display: flex; flex-wrap: wrap; justify-content: center;"><div id="3dmolviewer_17399137475650802"  style="position: relative; width: 1200px; height: 900px;">
#         <p id="3dmolwarning_17399137475650802" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17399137475650802 = null;
# var warn = document.getElementById("3dmolwarning_17399137475650802");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_17399137475650802 = null;
# viewergrid_17399137475650802 = $3Dmol.createViewerGrid(document.getElementById("3dmolviewer_
.37911867209999994 1.80196310409999993 -0.81464885529999997\nC  -2.62875184090000014 3.77320157599999995 -0.48140036570000000\nC  -1.27786789939999990 4.45292662119999960 -0.31040270310000001\nO  -3.47599322450000026 4.07883388020000037 0.63537113749999996\nC  -4.60282768370000017 3.31350267409999999 0.69444626249999997\nO  -5.44436930819999976 3.41331869680000022 1.55987115880000005\nC  -1.47763058399999991 0.39825257120000002 3.18572226009999993\nO  -0.97554162280000001 -0.85145465430000000 2.80578468429999983\nH  3.11285923739999992 -2.15446881030000004 0.10508273340000000\nH  6.66544110680000035 0.16226948070000000 -0.02104622200000000\nH  2.90447104619999985 2.07130941279999981 -0.48054539289999998\nH  -0.93968190099999993 0.01355098250000000 -0.47567347450000003\nH  -0.37305081480000002 -3.57222152840000007 -0.01745322300000000\nH  -2.17540083590000011 -5.25971617260000013 -0.00540868630000000\nH  -4.52706674710000012 -4.52642030460000022 -0.25076941030000000\nH  -3.25985397720000014 -0.49382303789999998 -0.53040779680000005\nH  -5.77978908079999965 0.80913317910000015 0.82877407979999995\nH  -6.11716758729999999 0.61840907519999999 -0.88570797499999998\nH  -6.90388716689999971 1.91775214990000009 0.04071163870000000\nH  -4.99127797470000001 2. ...
# 	viewergrid_17399137475650802[0][0].addLabel("U2 Reaction Complex ",{"position": {"x": 300.0, "y": 0, "z": 0}, "alignment": "topCenter", "fontSize": 24, "backgroundOpacity": 0, "fontColor": "black", "useScreen": true});
# 	viewergrid_17399137475650802[0][0].addLabel(" ",{"position": {"x": 300.0, "y": 450, "z": 0}, "alignment": "bottomCenter", "fontSize": 20, "backgroundOpacity": 0, "fontColor": "black", "useScreen": true});
# 	viewergrid_17399137475650802[0][1].addModel("36\nqcio_charge=0 qcio_multiplicity=1\nO  1.15973473230000002 -2.30311115559999990 -0.01506146170000000\nC  0.70561675729999995 -1.17447054279999996 -0.17380578299999999\nN  1.46402365150000002 -0.07581125360000000 -0.26625576509999999\nC  2.81272165999999979 -0.05275216520000000 -0.19725969030000001\nC  3.59297267899999984 -1.19801113919999991 -0.00079219700000000\nC  4.96201667620000020 -1.12216088890000010 0.06229430290000000\nC  5.78761634960000038 -2.38101330759999996 0.26649645270000000\nF  4.95695312680000022 -3.42254542329999989 0.46441177490000002\nF  6.53716541350000035 -2.58856079099999992 -0.83267767029999995\nF  6.58149611330000006 -2.20941715079999978 1.34046659250000011\nC  5.59101052270000043 0.10277849600000000 -0.07012622260000001\nC  4.84554161009999973 1.25141584219999991 -0.26466672590000001\nC  5.53755227789999971 2.59632970700000021 -0.41543845889999997\nF  6.34300975810000001 2.54930862070000019 -1.49346929640000003\nF  4.60344033570000022 3.55436719380000010 -0.57542250340000001\nF  6.26354016420000015 2.83670773289999989 0.69278313889999998\nC  3.47653788439999989 1.17367241169999992 -0.32726785120000002\nN  -0.67175840610000004 -0.95688184539999999 -0.26533568349999997\nC  -1.68508049790000003

# %% [markdown]
# ### Generate All the Fragments for out Calculations

# %%
for i, conf in enumerate(u2rc_conf.results.conformers):
    frags = generate_fragments(conf)
    for name, struct in frags.items():
        struct.save(frags_dir / f"{name}-{i}.json")

# %% [markdown]
# ## Now we're ready for some high throughput calculations!!
#
# Run the `5_compute.py` script to compute energy values for the reaction complex and all fragments.
